# %% [markdown]
# CLUSTER NAMES BY LLM
#
# LLM is given N randomal tweets from cluster.
# It is asked to: 1. suggest a name for the cluster  2. Give a reason 3. Decide if any tweets are far from the cluster .
# Caution- with no. 3 - sometimes the LLM is "too sensitive" - needs future prompt engineering.

# %%
df_clusters_path = '/content/drive/MyDrive/VieRally/test-set/clusters-captions.csv' # set path to df containing clustered tweets
df_tf_idf_path = '/content/drive/MyDrive/VieRally/test-set/clusters-names.csv'      # set path to df containing the tf-idf of each cluster
n_tweets_sample = 50                                                                # num of tweets randomly sampled from each tweet and sent to LLM to get a cluster name
engine = 'mistralai/Mistral-7B-Instruct-v0.3'                        # see https://huggingface.co/mistralai/Mistral-7B-v0.3, if LLM changed - query format might be changed
#optional
#hugging_face_key = 'XXXXXXXXX'

# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
import os
from random import shuffle
import requests
import time

# %%
df_clusters = pd.read_csv(df_clusters_path)
if 'Unnamed: 0' in df_clusters.columns:
    df_clusters = df_clusters.drop('Unnamed: 0', axis=1)
print(f'df_clusters contains {df_clusters.shape[1]} clusters, overall {df_clusters.size - df_clusters.isna().sum().sum()} tweets, and {df_clusters.isna().sum().sum()} NaNs')
# Out:
# df_clusters contains 52 clusters, overall 12499 tweets, and 16933 NaNs

# %%
# if tf-idf was done- it can be used for comparison
df_tf_idf  = pd.read_csv(df_tf_idf_path).reset_index(drop=True)

# %%
df_tf_idf.head()
# Out:
#    cluster number                          cluster name
# 0               0               ('life', 'fan', 'link')
# 1               1  ('ers', 'ninergang', 'sanfrancisco')
# 2               2  ('nfl', 'atlantafalcons', 'falcons')
# 3               3     ('ers', 'niners', 'sanfrancisco')
# 4               4           ('year', 'signing', 'deal')

# %%
# getting HuggingFace key, if not in colab, it is created in above first cell
from google.colab import userdata
hugging_face_key = userdata.get('H_FACE')

# %%
def query(prompt, engine=engine, temperature=0.01,max_tokens=400):

    """ sending a query to the LLM HuggingFace API
        returns the LLM's response
    """

    inputs = f'<s>[INST] {prompt} [/INST]'
    query ={"inputs":inputs  ,
            "parameters": {"temperature": temperature,"do_sample":False, "max_new_tokens": max_tokens, "max_time": 120},
            "options":{"wait_for_model":True}
            }
    API_URL = "https://api-inference.huggingface.co/models/"+engine
    headers = {"Authorization": "Bearer "+hugging_face_key}
    response = requests.post(API_URL, headers=headers, json=query)
    #print(response)
    out = response.json()
    #print(out)
    out = out[0]["generated_text"][len(inputs):]
    return(out)

# %%
#sanity check
query('how are you?')
# Out:
# "I'm just a computer program, so I don't have feelings or emotions. I'm here to help you with any questions you have to the best of my ability! How can I assist you today?"

# %%
import random
cluster_num_list, tf_idf_list, out_list, suggested_name_list, reason_list, examples_list = [] , [], [], [], [],[]
for col in df_clusters.columns:
    cluster_num = col.split('_')[1]
    cluster_num_list.append(cluster_num)
    print(f'****cluster # {cluster_num} ****')
    try:
        tf_idf = tuple(df_tf_idf[df_tf_idf['cluster number'] == int(cluster_num)]['cluster name'])[0]
        print('tf_idf: ', tf_idf)
        tf_idf_list.append(tf_idf)
    except:
        tf_idf_list.append(None)
    tweets_list = df_clusters[col].dropna().tolist()
    examples =  random.sample(tweets_list, 3) # 3 random samples from cluster
    examples_list.append(examples)
    print('cluster examples: ', examples)
    texts = random.sample(tweets_list, n_tweets_sample)
    prompt = f"""Here is a cluster of tweets. Suggest a name for the cluster, based on the majority of tweets.  Give answer in format:
            "Cluster suggested mame: xxx \n Short explanation (max 15 words): yyy \n  Tweets very far from the cluster (if any): aaa , a short reason (max 10 words). "
             Tweets cluster:{texts}"""
    out = query(prompt)
    out_list.append(out)
    print(out)
    suggested_name = out.split('\n')[0].split(':')[1]
    suggested_name_list.append(suggested_name)
    reason = out.split('\n')[1].split(':')[1]
    reason_list.append(reason)
    ##### add random sample of tweets from texts, explain why cluster name fits#####
    print('_______________________________________________________\n')
suggested_names_df = pd.DataFrame({'cluster_num': cluster_num_list, 'LLM_suggested_cluster_name': suggested_name_list , 'LLM_reasoning': reason_list,
                                   'tf_idf': tf_idf_list , 'examples': examples_list})
display(suggested_names_df)
# Out:
# ****cluster # 0 ****
# tf_idf:  ('life', 'fan', 'link')
# cluster examples:  ['Explore our selection fan gear designed elevate your Team support Click the link our bio for exciting shopping experience that awaits you TampaBayBuccaneers GoBucs BuccaneersNation BuccaneersFootball BucsPride BucsCountry BucsFans Bucs Life BucsGameDay BucsFamily BucsWin BucsLove BucsNationUnite BucsUp BucsSupport BucsStrong BucsHuddle BucsCheer BucsCrazies BucsForTheWin BucsUnited BucsCommunity BucsForever BucsLegacy BucsGameday BucsFootballClub BucsFansUnite BucsTeam BucsRoar BucsNationRise', 'Explore our selection fan gear designed elevate your Team support Click the link our bio for exciting shopping experience that awaits you IndianapolisColts ColtsNation ForTheShoe ColtsFootball ColtsPride ColtsCountry ColtsFans Colts Life ColtsGameDay ColtsFamily ColtsWin ColtsLove ColtsNationUnite ColtsUp ColtsSupport ColtsStrong ColtsHuddle ColtsCheer ColtsCrazies ColtsForTheWin ColtsUnited ColtsCommunity ColtsForever ColtsLegacy ColtsGameday ColtsFootballClub ColtsFansUnite ColtsTeam ColtsRoar ColtsFlock', 'Explore our selection fan gear designed elevate your Team support Click the link our bio for exciting shopping experience that awaits you IndianapolisColts ColtsNation ForTheShoe ColtsFootball ColtsPride ColtsCountry ColtsFans Colts Life ColtsGameDay ColtsFamily ColtsWin ColtsLove ColtsNationUnite ColtsUp ColtsSupport ColtsStrong ColtsHuddle ColtsCheer ColtsCrazies ColtsForTheWin ColtsUnited ColtsCommunity ColtsForever ColtsLegacy ColtsGameday ColtsFootballClub ColtsFansUnite ColtsTeam ColtsRoar ColtsFlock']
# Cluster suggested name: NFL Fan Gear
#    Short explanation (max 15 words): Tweets about NFL team fan gear.
#    Tweets very far from the cluster (if any): None, all tweets are about NFL teams and their fan gear.
# _______________________________________________________
#
# ****cluster # 1 ****
# tf_idf:  ('ers', 'ninergang', 'sanfrancisco')
# Short explanation: Discussions about NFL free agency signings and potential signings.
# Tweets very far from the cluster (if any): Odell Beckham Jr. wanting to join the Kansas City Chiefs, which is more about a player's free agency decision rather than a signing. A short reason: It is not about the NFL free agency signings, but about a player's desire to join a team.
# _______________________________________________________
#
# ****cluster # 5 ****
# tf_idf:  ('newyorkartist', 'newyorkgiants', 'newyork')
# cluster examples:  ['have the PRETTIEST clients Loving the placement the color the cut chefs kiss And God WISH that took before', 'repost tinyy 𝕿𝖍𝖊 𝖋𝖚𝖈𝖐𝖊𝖓 𝕽𝕬𝕴𝕯𝕰𝕽𝕾 raiders tinys lashes raidernation raiders raidersfootball dickies cortez fit chola ganstalife califas raza brownpride oldschool fresno windbreakers creased makeup rosario cencal centralvalley lasvegasraiders oldsoul chicana xicana mexicana saesthetic milf yomomma explore', '𝐀𝐂𝐄 𝐍𝐚𝐢𝐥𝐬 𝐒𝐩𝐚 Camp Wisdom Dallas United States Texas dallasnailsalon DACEnailsandspa nailartist NailDesigns dallasnailtech dallasnails music tiktoker tiktokviral dallascowboys northdallas dallas dallastx nailsoftiktok nailart southdallas dallasthingstodo']
# Cluster suggested name: Beauty & Barbershop
# Short explanation: Tweets about various beauty services, haircuts, and barber shops.
# Tweets very far from the cluster (if any): 'Get BIGGER PENIS and LONGER Without Surgery Get Rid Off ERECTILE DYSFUNCTION and LAST LONGER also with Premature Ejaculation and weak erection you want more vascular Muscle get rid off Belly fat and body fat for more info visit website www dradamokpoko com adamokpoko gmail com official pages adamokpoko adamokpoko Google search Adam okpoko dmvstyle campuslife washingtondc maryland virginia northcarolina southcarolina atlanta nyc california florida foe DMV klipperkingsofcharlotte charlotte queencity northcarolina charlottebarber charlottebarbershop ncbarber ncbarbershop queencitybarber charlottehornets buzzcity carolinapanthers keep pounding faded beard fvded fvdrseason'. This tweet is about a completely different topic, not related to beauty or barber shops.
# _______________________________________________________
#
# ****cluster # 6 ****
# tf_idf:  ('nfl', 'chargers', 'losangeleschargers')
# cluster examples:  ['The Chargers have agreed terms bring back Easton Stick per Mike Garofolo Stick threw for yards five games four starts for the team last season', 'Prizm Isaiah Spiller rookie blue ice Surprisingly Spiller the highest paid under contract now after the Chargers decided not use the franchise tag Ekeler and Kelly also becoming This most certainly won the case over the offseason How cool would see Saquon for years', 'Former Chargers Eric Kendricks has had change heart and now signing with the Cowboys instead the ers per adamschefter Looks like would rather lose the first round the playoffs than win Super Bowl FTTB FOLLOW SFNinerUpdates FOR MORE goniners ers ers ersfaithful ersnation ers life ersempire ersfootball ersgang ersallday ersfamily ers sanfrancisco ers ersforlife Quest Six Superbowl bangbangninergang niners ninergang ninerempire ninernation ninersnation ninersfaithful ninersforlife nflmemes nflcheerleaders nflnews ersfan ersgame']
# Cluster suggested name: NFL Free Agency Discussions
# Short explanation: Tweets discussing NFL free agency moves, trades, and signings.
# Tweets very far from the cluster (if any): "Chargers fans how are feeling today" - This tweet does not discuss free agency but rather the general mood of Chargers fans. It is not directly related to the majority of tweets in the cluster.
# _______________________________________________________
#
# ****cluster # 7 ****
# tf_idf:  ('nfl', 'arizonacardinals', 'cardinals')
# cluster examples:  ['The Cardinals signed former Seahawks running back Deejay Dallas Well this surprises little but about time Dallas seems like very slow kick returner wish him the best Arizona Let know your opinion the comments seattleseahawks seahawksnation gohawks seahawkers seahawks nfl thman', 'The AZCardinals are Signing Kieth Ismael azcardinals nfl arizonacardinals arizona cardinals kylermurray football riseupredsea birdgang larryfitzgerald cardinalsfootball beredseered deandrehopkins redsea chandlerjones nfldraft buddabaker patrickpeterson nfcwest phoenix nflnews phoenixsuns explorepage nfc beredseared nflfootball arizonacardinalsfootball', 'The AZCardinals Have Agreed Terms With Star Sean Murphy Bunting']
# Cluster suggested name: Arizona Cardinals Free Agency Signings
# Short explanation: Tweets about the Arizona Cardinals signing various players during the NFL free agency period.
# Tweets very far from the cluster (if any): "Suns Try Tame The Celtics The Cardinals Are Something Join TONIGHT March MST for Heat Check LIVE Suns Celtics Recap East Coast Trip NBA Playoff Push NFL Free Agency Arizona Cardinals Moves Like Subscribe our YouTube Page stay touch with everything Valley Sports Link Bio phoenixsuns nflfreeagency arizonacardinals kevindurant devinbooker" - This tweet is about the Phoenix Suns basketball team, not the Arizona Cardinals. It is not about free agency signings, but about a game against the Celtics.
# _______________________________________________________
#
# ****cluster # 8 ****
# tf_idf:  ('click', 'range', 'fantastic')
# cluster examples:  ['Wear your Team pride with our exclusive range fan apparel and accessories Click the link our bio and uncover world fantastic products TampaBayBuccaneers GoBucs BuccaneersNation BuccaneersFootball BucsPride BucsCountry BucsFans Bucs Life BucsGameDay BucsFamily BucsWin BucsLove BucsNationUnite BucsUp BucsSupport BucsStrong BucsHuddle BucsCheer BucsCrazies BucsForTheWin BucsUnited BucsCommunity BucsForever BucsLegacy BucsGameday BucsFootballClub BucsFansUnite BucsTeam BucsRoar BucsNationRise', 'Wear your Team pride with our exclusive range fan apparel and accessories Click the link our bio and uncover world fantastic products IndianapolisColts ColtsNation ForTheShoe ColtsFootball ColtsPride ColtsCountry ColtsFans Colts Life ColtsGameDay ColtsFamily ColtsWin ColtsLove ColtsNationUnite ColtsUp ColtsSupport ColtsStrong ColtsHuddle ColtsCheer ColtsCrazies ColtsForTheWin ColtsUnited ColtsCommunity ColtsForever ColtsLegacy ColtsGameday ColtsFootballClub ColtsFansUnite ColtsTeam ColtsRoar ColtsFlock', 'Wear your Team pride with our exclusive range fan apparel and accessories Click the link our bio and uncover world fantastic products ArizonaCardinals RedSea BirdGang AZCardinals CardinalsNation BeRedSeeRed CardinalsFootball AZSports NFL Football GoCards CardinalsFans CardinalsPride CardinalsCountry CardinalsGameDay CardinalsFamily CardinalsWin Cardinals Life CardinalsForTheWin CardinalsUnited CardinalsLove CardinalsSupport CardinalsRise CardinalsFlock CardinalsCheer CardinalsCrazies CardinalsHuddle CardinalsNationRise CardinalsStrong CardinalsFansUnite']
# Cluster suggested name: NFL Teams Pride
#    Short explanation: Tweets promoting fan apparel and accessories for various NFL teams.
#    Tweets very far from the cluster (if any): 'Wear your Team pride with our exclusive range fan apparel and accessories Click the link our bio and uncover world fantastic products WashingtonCommanders Commanders' - This tweet is about a specific team (Washington Commanders) not included in the majority of the cluster.
# _______________________________________________________
#
# ****cluster # 9 ****
# tf_idf:  ('pittsburghsteelers', 'steelers', 'pittsburgh')
# cluster examples:  ['honor Patrick Queen and Deshone Elliot coming over the right side the Steelers Ravens rivalry here are some players that have been both sides the rivalry that have played for both Pittsburgh and Baltimore via dylanwdesign Use code STEELERSFANS Seat Geek save off your first purchase steelers steelersnation herewego benroethlisberger kennypickett camheyward sports pittsburgh terribletowel georgepickens stairwaytoseven steelerscountry minkahfitzpatrick steelcurtian najeeharris troypolamalu tjwatt nfl football superbowl collegefootball mvp mlb soccer nba nhl baseball worldcup miketomlin pittsburghsteelers', 'NFL Prediction Tyler Boyd Signs with Pittsburgh Steelers NFL tylerboyd afcnorth cincinnatibengals joeburrow teehiggins pittsburghsteelers russellwilson georgepickens miketomlin kennypickett nflfreeagency nflpredictions patrickqueen https youtube com shorts EfPGZ aHIRY feature share', 'The Steelers have signed Van Jefferson one year deal Welcome Pittsburgh van steelers steelersnation steelersfootball steelerscountry steelersfan diontaejohnson omarkhan steelersnews steelersnationunite weekone steelersfan nation pittsburgh pittsburghsteelers minkahfitzpatrick camheyward afcnorth acrisurestadium russellwilson alexhighsmith tjwatt nflmockdraft ravens pittsburgh madden najeeharris nfl nfldraft nflfootball nflplayoffs nflnews']
# Cluster suggested name: Steelers Signings
# Short explanation: Discusses the Pittsburgh Steelers signing multiple players, including Russell Wilson, Patrick Queen, and Van Jefferson.
# Tweets very far from the cluster (if any): "Watt Pittsburgh Steelers present nfl football pittsburghsteelers tjwatt custompainted custompaintedfigures citadelpaints mcfarlanetoys mcfarlanefigures inchfigure" - This tweet is about a custom painted figure of T.J. Watt, not about the Steelers signing players.
# Short reason: This tweet is about a custom painted figure, not about the Steelers signing players.
# _______________________________________________________
#
# ****cluster # 10 ****
# tf_idf:  ('nfl', 'washingtoncommanders', 'commanders')
# cluster examples:  ['Cardinals are signing Jonah Williams year deal washington washingtoncommanders commandersnation commandersnation', 'REAVOOOOOOOO WashingtonCommanders JeremyReaves httc', 'BobbyWagner signs with the Commanders commanders washingtoncommanders ekeler chargers jimharbough lachargers nfl nflfreeagency freeagency like likes graphicdesign sports football nflmemes nflnews']
# Cluster suggested name: Washington Commanders Free Agency Signings
# Short explanation: Tweets about the Washington Commanders signing various players during the NFL free agency period.
# Tweets very far from the cluster (if any): "Commanders Guard Saahdiq Charles signing with the Tennessee Titans" - This tweet is about a player leaving the Commanders, not joining them. A short reason: Saahdiq Charles is leaving the Commanders.
# _______________________________________________________
#
# ****cluster # 11 ****
# tf_idf:  ('nfl', 'texans', 'houstontexans')
# cluster examples:  ['Breaking The Texans are signing former Bills and Commanders Tim Settle deal worth per mike garafolo Thoughts', 'The Houston Texans are signing Noah Brown Are you even Texans fan you aren following texansriot Don forget follow texansriot right now for the best Texans Updates and more Ignore Tags texans nfl houston houstontexans football texas sports nflnews htown deshaunwatson colts nflfootball wearetexans titans texansnation nflmemes houstontx patriots texansfootball jaguars steelers afcsouth nfldraft astros htx chiefs saints jjwatt packers broncos', 'DanielleHunter HoustonTexans Texans Houston NFL Football allsportsnews sportsnews sports breakingnews news']
# Cluster suggested name: Houston Texans Offseason Moves
# Short explanation: Tweets discussing the Houston Texans' offseason signings and trades.
# Tweets very far from the cluster (if any): "cjstroud whodoyoucollect prizmfootball houstontexans houstontx" - This tweet is about a specific football card collection, not related to the Texans' offseason moves.
# Short reason: It discusses a specific football card collection, not the Texans' offseason moves.
# _______________________________________________________
#
# ****cluster # 12 ****
# tf_idf:  ('nfl', 'sports', 'football')
# cluster examples:  ['Greatest receiver all time Beautiful PSA Type Jerry Rice action shot Messerschmidt jerryrice ers sanfrancisco ers almesserschmidt type photo', 'MADE PODCAST CLICK THE LINK BIO Make sure check out Like and subscribe will dropping more episodes shootingfortheendzone philadelphia philly jalenhurts gobirds eagles philadelphiaeagles flyeaglesfly flyeaglesfly nfl football hurts nfl football phillysports jamesbradberry ajbrown jasonkelce kelce devontasmith brianjohnson skinnybatman smitty newheights', 'Signed photo quarterback Gino Torretta who led the University Miami two national championships won the Heisman Trophy was unanimous All American who won the Maxwell Award Walter Camp Award Davey Brien Award and the Johnny Unitas Golden Arm Award saw limited action with five teams during his NFL career became financial advisor and the CEO Touchdown Radio which broadcasts college football games was inducted into the College Football Hall Fame The Miami Hurricanes have retired his number Gino now years old nfl nflfootball nflsunday nflseason footballplayer football footballgame footballseason footballfans footballlife footballsunday footballislife footballtime footballplayers miamihurricanesfootball heismantrophy indianapoliscolts seattleseahawks sanfrancisco ers detroitlions minnesotavikings ginotorretta ginotorretta']
# Cluster suggested name: NFL Free Agency Updates
# Short explanation: Tweets discussing NFL free agency news, player signings, and team updates.
# Tweets very far from the cluster (if any): 'Brad Johnson via TTM days buccaneers tampabaybuccaneers vikings minnesotavikings bradjohnson ttmsuccess ttmautograph ttm pinnacle topps toppschrome footballcards tradingcards nfl probowl superbowl autograph Sent Received Minnesota Vikings Games Washington Redskins Games Tampa Bay Buccaneers Games Dallas Cowboys Super Bowl Champion Pro Bowl Record Completions Yards Touchdowns Interceptions Quarter Comebacks Game Winning Drives Rushes Yards Touchdowns Receptions Yard Touchdown Passer Rating Games' - This tweet is about a specific player's career statistics and achievements, rather than free agency news.
# _______________________________________________________
#
# ****cluster # 13 ****
# tf_idf:  ('paniniamerica', 'hof', 'baltimoreravens')
# cluster examples:  ['The sun out spring near and have great collection Provence rosé for you try Currently are running special America best selling rosé Whispering Angel for only Member pricing you like the taste Whispering Angel but are interested more robust flavor try Rock Angel the winery barrel aged offering which adds bit more nuance and complexity the wine with notes coconut and vanilla deriving from the barrel The Beach Whispering Angel more focused the summer fruits with notes raspberries strawberries and peaches While still typical dry style rosé more approachable for new drinkers the varietal Then have personal favorite Minuty Chateau Minuty While Whispering Angel the top selling rosé stateside Minuty the best seller France This rosé focu
# cluster examples:  ['just leave this here KNEW this was coming justinfields chicagobears', 'The Bears made surprising trade for long time Chargers Keenan Allen Thursday night giving round pick the deal The year old Allen didn show any signs slowing down putting catches for yards and TDs games Another weapon for Caleb Williams and the Bears KeenanAllen Chicago ChicagoBears DaBears Trade NFL NFLNews Sports SportsArt SportsDesign JerseySwap', 'chicagobears bearsgootball dabears beardien']
# Cluster suggested name: Chicago Bears Offseason Moves
# Short explanation: Discusses trades and signings by the Chicago Bears during the offseason.
# Tweets very far from the cluster (if any): "mood everyday that goes and ryan poles hasn announced his decision impatient person nature and hate waiting just tell that why hate surprises believe not nah get poles wanting take his time cause this big decision has make sure his are dotted and his are crossed even means all are just sitting the gray just want the best for justin the bears and whatever else comes next but also know that you wanna trade him let him free can start studying film just hate how much his name being dragged through the mud the longer poles drags this out does all the right things never gets trouble and just working hard yet the media trying paint this nasty narrative about justin that really why want decision made cause getting worse the day unfair justin and hate for him everyone media included needs better happy thursday justinfields ohiostate nfl football quarterback chicago chicagobears beardown bears bearsnation halashall soldierfield ryanpoles matteberflus freeagency offseason nfldraft training buckeyes buckeyenation gobucks thursday blessed"
# Short reason: This tweet is very far from the cluster as it expresses personal feelings and opinions about Justin Fields, rather than discussing trades and signings by the Chicago Bears.
# _______________________________________________________
#
# ****cluster # 16 ****
# tf_idf:  ('jaguars', 'nfl', 'jacksonvillejaguars')
# cluster examples:  ['How you feel about the Jags WRs following free agency Should the Jags target receiver with their pick DTWD DUUUVAL IWATJ Jaguars Jacksonville JacksonvilleJaguars Jags GoJags GoJaguars TrevorLawrence Football Sports NFL', 'Jaguars are signing Gabe Davis year deal per rapsheet breaking football footballupdate footballnews footballreport sports Sports sportsnews sportsupdate nflupdates nflfootball nflnews NFL nfl jacksonville jaguars jacksonvillejaguars allsportstrades', 'Jacksonville Jaguars signed Gabe Davis will also get signing with incentives that could make worth The deal will official March Information was told The Athletic Dianna Russini well Adam Schefter indicated the signing was selected the fourth round the Buffalo Bills Buffalo Bills REC TGTS YDS AVG TDS LNG FUM LST nfl football jacksonvillejaguars']
# Cluster suggested name: Jacksonville Jaguars Free Agency
# Short explanation: Discusses the Jaguars' offseason signings and trades.
# Tweets very far from the cluster (if any): "Corey Davis coming out retirement after one season and reunion with the Jets play per Field Yates The team will release Davis from the Retirement Reserve list today They will probably work new friendly contract jets jetsfootball jetsfan jetsnews jetsnation jetup afceast jetsjetsjets newyorkjets nfl nflfootball nflseason nflplayoffs nfloffseason nflsunday nflfreeagency coreydavis" - This tweet is about Corey Davis rejoining the Jets, not the Jaguars.
# _______________________________________________________
#
# ****cluster # 17 ****
# tf_idf:  ('detroit', 'lions', 'detroitlions')
# cluster examples:  ['Breaking The Lions have agreed terms with Marcus Davenport one year deal per mike garafolo Follow detlionsdfa for more Lions Detroit DetroitLions DetroitLionsNFL NFL Football DET Lion Team Draft Game OnePride LionsNews sports Explore Explorepage News Rumor InstaSports', 'Report Detroit Lions bolster defense adding Buccaneers cornerback Carlton Davis https www clickondetroit com sports report detroit lions bolster defense adding buccaneers cornerback carlton davis DetroitLions CarltonDavis', 'The DetroitLions have signed Reader year million contract Welcome Detroit djread Lions DefendtheDen NFL FreeAgency OnePride Detroit MotorCity Football LionsWonAgain BradHolmes DanCampbell AllGrit Like Share']
# Cluster suggested name: Eventful Weekends in the South
# Short explanation: A collection of tweets about upcoming events, food, and entertainment in cities like New Orleans, Dallas, Tampa, and Houston.
# Tweets very far from the cluster (if any): 'sugar cookies', 'Something different about Fridays', 'Relaxing Chilling DENVER', 'never too early start your Summer shopping', 'Bitcoin the beginning something great', 'Low sensory morning this Sunday March', 'You can see everything marialevine what you want home page web Big tits bradenton vip consurso tampanightlife centralflorida handmadebag luxurybag designerbags handmadepurse poems nasty eroticlingerie poetry spokenwordpoetry openmic tampabae tampabaybuccaneers superbowlchamps eroticauthor lovepoems lovewins valentines' - These tweets are not about events, food, or entertainment in the South, and are not related to the majority of the tweets in the cluster.
# _______________________________________________________
#
# ****cluster # 20 ****
# tf_idf:  ('click', 'life', 'fan')
# cluster examples:  ['Customize your outfit with our mix and match options for truly unique fan style Don miss out our amazing products click shop our bio today LasVegasRaiders RaiderNation JustWinBaby RaidersFootball SilverAndBlack RaidersPride RaidersNation RaidersFamily RaidersFans Raiders Life RaidersGameDay RaidersWin RaidersLove RaidersNationUnite RaidersUp RaidersSupport RaidersStrong RaidersHuddle RaidersCheer RaidersCrazies RaidersForTheWin RaidersUnited RaidersCommunity RaidersForever RaidersLegacy RaidersGameday RaidersFootballClub RaidersFansUnite RaidersTeam RaidersRoar', 'Elevate your fan fashion game with our chic attire perfect for game day everyday wear Your shopping spree just click away start now BuffaloBills BillsMafia GoBills BillsNation BillsMafiosa BillsMafia Life BillsFootball BuffaloBillsFans BillsPride BillsCountry BillsMafiaFamily BillsWin BillsGameDay BillsMafiaLove BillsUp BillsSupport BillsStrong BillsHuddle BillsCheer BillsCrazies BillsForTheWin BillsUnited BillsLove BillsFamily BillsGang BillsFansUnite BillsLegacy BillsCommunity BillsNationRise BillsForever', 'Customize your outfit with our mix and match options for truly unique fan style Don miss out our amazing products click shop our bio today LosAngelesRams RamsHouse MobSquad RamsNation RamsFootball RamsPride RamsCountry RamsFans Rams Life RamsGameDay RamsFamily RamsWin RamsLove RamsNationUnite RamsUp RamsSupport RamsStrong RamsHuddle RamsCheer RamsCrazies RamsForTheWin RamsUnited RamsCommunity RamsForever RamsLegacy RamsGameday RamsFootballClub RamsFansUnite RamsTeam RamsRoar']
# Cluster suggested name: NFL Fan Fashion
#  Short explanation (max 15 words): Tweets promoting NFL team merchandise.
#   Tweets very far from the cluster (if any): None, all tweets are about NFL teams and their merchandise.
# _______________________________________________________
#
# ****cluster # 21 ****
# tf_idf:  ('chiefs', 'nfl', 'kansascitychiefs')
# cluster examples:  ['Hollywood heads Marquise Brown signs with the Chiefs year deal worth Commission made for primetime jet and collegefootballedits Chiefs three peat next year', 'Another great season flag football the books Chiefs kcchiefs chiefs kansascitychiefs flagfootball redkingdom footballplayer footballseason', 'told yall have the script chiefs mahomes kelce afc afcwest chiefskingdom chrisjones football footballplayer chiefsnation chiefsnation chiefsfootball chiefsfan kcmo kcchiefs kansascitychiefs sacknation nflfootball nflnews footballseason tyreekhill isaiahpacheco superbowl playoffs grind gochiefs chrisjones rasheerice afcfootball nfl nfc nflnews chiefsnews']
# Cluster suggested name: Chiefs Fan Central
# Short explanation: Focus on Kansas City Chiefs and related topics.
# Tweets very far from the cluster (if any): "TEENYMATES SERIES rare Kansas City Chiefs MVP Patrick Mahomes teenymates nfl kansascitychiefs patrickmahomes rare mvp", "Happy Birthday Walkoff chiefs nfl kcchiefs pachecofx football americanfootball mahomes pacheco patrickmahomes isiahpacheco creedhumphrey rasheerice rice rashee creed humphrey chrisjones chris jones traviskelce travis kelce taylorswift taylor swift america usa american kansascity kansascitychiefs", "Saints sign former Chiefs Willie Gay one year deal worth max million This one HURTS Willie did warn this was his last game with and wow what fun player was One the most charismatic the sideline and team leader have his signed jersey and predicted the Chiefs would draft him the second round obviously have been rooting for him gets join khalennotkaylen who another great chief personality get paid Nola Best luck Willie sure follow UpperhandChiefs for more hype content throughout the off season chiefs kansascity kansascitychiefs chiefsnation kcchiefs chiefsfootball nfl kcmo chiefskingdom patrickmahomes mahomes traviskelce kelce nflplayoffs playoffs superbowl offseason nfloffseason nfldraft nfldraft nflcombine draft freeagency nflfreeagency nfltrade trade". These tweets are about Patrick Mahomes, Taylor Swift, and Willie Gay, who are not directly related
# _______________________________________________________
#
# ****cluster # 22 ****
# tf_idf:  ('eagles', 'year', 'deal')
# cluster examples:  ['BREAKING The Eagles are signing Devin White one year deal FlyEaglesFly', 'ITS HOWIE SEASON HowieRoseman just traded for backup Quarterback that can win you games for the philadelphiaeagles PhiladelphiaEagles KennyPickett Who Also Grew Eagles Fan Was This Great Move NFL', 'excited hear the news that our longtime friend Saquon Barkley joining the Philadelphia Eagles Sending huge congratulations and best wishes Saquon this incredible new chapter Here throwback snap with our Business Development Manager Jason Schlaffer and Regional Director Business Development Brian Martin Cheers your continued success Saquon PhiladelphiaEagles SaquonBarkley saquon']
# Cluster suggested name: "Eagles Free Agency Signings"
# Short explanation: This cluster of tweets is about the Philadelphia Eagles signing several free agents, including Devin White, Saquon Barkley, and Josh Sweat.
# Tweets very far from the cluster (if any): "Saquon Barkley leaving the Giants sign with the rival Eagles NFL free agency Gridironheights nfl collegefootball onepride lamarjackson detroitlions wearetexans jerseyswap bighits jukes fumble widereceiver deshaunwatson houstontexans highschoolfootball joeflacco ncaafootball tombrady heisman jjwatt nflseason tjwatt billbelichick justinherbert joeburrow michiganwolverines jimharbaugh" - This tweet is about various NFL and college football players, not specifically about the Eagles free agency signings.
# _______________________________________________________
#
# ****cluster # 23 ****
# tf_idf:  ('nfl', 'sports', 'football')
# cluster examples:  ['need Hunter like need air How would you rank these free agent pass rushers According JMB Twitter rumor has Falcons are holding moves until Hunter chooses would huge hit their remaining cap space and they want make sure have the money available vikings nfl nflnews', 'Jeff Duncan The Saints will soon release Michael Thomas shouldn have ended this way SWIPE see Thomas reaction Sad day', 'Reminder that Howell just young some these top prospects the draft']
# Cluster suggested name: NFL Free Agency Preview
# Short explanation: Discusses upcoming free agency moves in the NFL.
# Tweets very far from the cluster (if any): 'Throwback Todd Gurley destroying Broncos run defense for over yards and touchdowns back nfl' - This tweet is about a past game and not related to free agency. 'Anthony Richardson Freshman Fabric anthonyrichardson indianapoliscolts nfl' - This tweet is about the NFL Draft, not free agency. 'Kirk Cousins was pace for MVP type season before his injury SWIPE Follow bulldogsandfalcons for more' - This tweet is about a player's past performance, not related to free agency. 'What everyone thoughts the Carlton Davis trade and the round pick Buccaneers received from comment down below' - This tweet is about a trade, not free agency. 'What impresses most about Willie Gay his ability read plays His speed and explosiveness huge bonus and think impact our defense lot just did the Chiefs only years old and that the best part about This signing was underrated Would love could eventually replace Demario Davis when retires saints whodat whodatnation saintsnews Saintsupdates neworleanssaints saintscoverage' - This tweet is about a player signing with a team, not free agency. 'NFL legend Hall Famer Tony Gonzalez played for the Miami Heat Summer League team while the midst NFL offseason The Gonzalez had combined stats PTS REB MIN two games Gonzalez played three years college basketball Cal then tried out for the Portland Trail Blazers didn make the team but was also recruited play basketball overseas Then Miami Heat President Pat Riley said Gonzalez could have been NBA pro dedicated enough time because his rebounding defense was
# _______________________________________________________
#
# ****cluster # 24 ****
# tf_idf:  ('jones', 'nfl', 'aaron')
# cluster examples:  ['BREAKING Minnesota Vikings jjettas reportedly turned down and extension excess million year before the season per adamschefter', 'Vikings future HOF Safety Harrison Smith has agreed restructure his contract and will play season for the Vikings per TomPelissero', 'The Vikings have not made Dalton Risner offer this morning Darren Wolfson mentioned skornorth would like back Minnesota but also wants off the board over the next hours Risner has least one option around the league that not Minnesota']
# Cluster suggested name: Vikings Free Agency Signings
# Short explanation: The majority of tweets discuss the Minnesota Vikings signing various free agents, including running backs Aaron Jones and Josh Jacobs, safety Xavier McKinney, and others.
# Tweets very far from the cluster (if any): The tweets about the Saints losing Lonnie Johnson to free agency and the Packers signing Josh Jacobs are somewhat related, but they are not about the Vikings, so they are not part of the cluster.
# Short reason (max 10 words): Not about the Vikings.
# _______________________________________________________
#
# ****cluster # 25 ****
# tf_idf:  ('size', 'website', 'available')
# cluster examples:  ['Nike Off White Summit White Psychic Purple Air Terra Forma Size Available Store and Website', 'The new waterproof Under Armour Charged Valsetz side zip boot has arrived Harry and incredible Sizes available You have try these Priced underarmour boots blackboots footwear sidezip police policeofficer securityofficer coolstuff coolboots comfyboots military detroitlions detroittigers army usmc usnavy usaf underarmourshoes survival usa america', 'Jordan Dunk From Above Size Jordan University Gold Size Available Store and Website']
# Cluster suggested name: Sneaker Releases
# Short explanation: Tweets about new and vintage sneakers available for purchase.
# Tweets very far from the cluster (if any): "Dallas Cowboys Pro Player Puffer size Sold before posted" - This tweet is about a sold-out item, not a sneaker release.
# _______________________________________________________
#
# ****cluster # 26 ****
# tf_idf:  ('keeppounding', 'carolinapanthers', 'panthers')
# ...
# _______________________________________________________
#
# ****cluster # 50 ****
# tf_idf:  ('nfl', 'giants', 'newyorkgiants')
# cluster examples:  ['Patriots Jalen Mills joining the New York Giants newenglandpatriots nfl patriots patsnation football newengland patriotsnation tombrady pats patriotsfootball gopats superbowl nflfootball boston gillettestadium lfg sports nflnews julianedelman billbelichick patriotsfan gopatriots afc camnewton gronk afceast foxboro doyourjob patsfan', 'Tiki Barber has love lost for Saquon Barkley after signing with the Philadelphia Eagles Use code GMENWORLD SeatGeek for off your first purchase Follow gmen world for daily Giants content nyg newyorkgiants newyorkgiantsfootball giants nygiants football nfl bigblue giantspride togetherblue gmenszn giantsnews giantsdaily giantsupdates giantsforever giantsnation gmen world bigblueny bigbluenewyorkgiants giantsnationallday giantsbreakingnews nyfootballtalk giantstoday bigbluenewyorkgiants gmennews footballseason nfceast', 'Giants have signed Jermaine Eluemunor Follow thenygiantsnews for Giants News and Coverage nyg nygiants newyorkgiants football nfl giants giantspride gobigblue giantsnews giantsbreakingnews giantsupdates gmen gmennation footballplayer giantsfootball Begiant giantscountry footballseason']
# Cluster suggested name: Giants Offseason Moves
# Short explanation: Tweets discussing the New York Giants' offseason signings and acquisitions.
# Tweets very far from the cluster (if any): "wow Giants fans must need some Wellbutrin right Birds philadelphiaeagles eagles newyorkgiants saquonbarkley runningback nfl freeagency nflfreeagency" - This tweet is far from the cluster as it expresses frustration towards the Giants and mentions a player (Saquon Barkley) who has left the team, rather than discussing new signings.
# _______________________________________________________
#
# ****cluster # 51 ****
# tf_idf:  ('cleveland', 'browns', 'clevelandbrowns')
# cluster examples:  ['With the addition former round pick Jerry Jeudy this Browns room has some TALENT via NFL', 'Dawg check Myles Garrett Orange pulsar dawgnation dawgcheck clevelandbrowns mylesgarrett', 'Omfg clevelandbrownsfancruise clevelandbrowns Nerding out']
# Cluster suggested name: Browns Offseason Moves
# Short explanation: Tweets discussing the Cleveland Browns' offseason transactions, including player signings and trades.
# Tweets very far from the cluster (if any): "These Brownies want everyone know just how much they love the Cleveland Browns Check out these awesome cabin door decorations that some our creative cruisers put together Which one your favorite brownsfancruise herewegobrownies brownsfan brownsfans clevelandbrowns clevelandbrownsfan eva royalcaribbeancruises independenceoftheseas dawgpoundnation"
# Short reason: Tweet is about Browns fans' cabin door decorations, not about offseason moves.
# _______________________________________________________
#    cluster_num                         LLM_suggested_cluster_name  \
# 0            0                                       NFL Fan Gear
# 1            1                           NFL Free Agency Signings
# 2            2                        Falcons' Offensive Overhaul
# 3            3                                  Sports and Family
# 4            4                        NFL Free Agency Discussions
# 5            5                                Beauty & Barbershop
# 6            6                        NFL Free Agency Discussions
# 7            7             Arizona Cardinals Free Agency Signings
# 8            8                                    NFL Teams Pride
# 9            9                                  Steelers Signings
# 10          10         Washington Commanders Free Agency Signings
# 11          11                     Houston Texans Offseason Moves
# 12          12                            NFL Free Agency Updates
# 13          13                              Sports & Collectibles
# 14          14                             Cowboys Roster Changes
# 15          15                      Chicago Bears Offseason Moves
# 16          16                   Jacksonville Jaguars Free Agency
# 17          17                         Lions Free Agency Signings
# 18          18                                 Sports Fans United
# 19          19                     Eventful Weekends in the South
# 20          20                                    NFL Fan Fashion
# 21          21                                 Chiefs Fan Central
# 22          22                      "Eagles Free Agency Signings"
# 23          23                            NFL Free Agency Preview
# 24          24                       Vikings Free Agency Signings
# 25          25                                   Sneaker Releases
# 26          26                  Carolina Panthers Offseason Moves
# 27          27                        Ravens Free Agency Signings
# 28          28                                  NFL Game Day Fans
# 29          29                                      Eagles Nation
# 30          30                       Packers Free Agency Signings
# 31          31                      Seahawks Free Agency Signings
# 32          32             "Aaron Donald Retirement Announcement"
# 33          33                Miami Dolphins Free Agency Signings
# 34          34                                           NFL Fans
# 35          35              "Steelers-Eagles Kenny Pickett Trade"
# 36          36                             Sports Fans Gift Guide
# 37          37                                      Raider Nation
# 38          38                 Jets Offensive Line Reinforcements
# 39          39                                   NFL Rookie Cards
# 40          40   Real Estate, Home Improvement, and Cleaning S...
# 41          41                           NFL Free Agency Signings
# 42          42                          Colts Free Agency Updates
# 43          43                         Chargers Fan Gear Shopping
# 44          44                        Titans Free Agency Signings
# 45          45                      Patriots Free Agency Signings
# 46          46                                       NFL Fan Gear
# 47          47          Tampa Bay Buccaneers Free Agency Signings
# 48          48                             Sports Card Collectors
# 49          49                              Giants-Panthers Trade
# 50          50                             Giants Offseason Moves
# 51          51                             Browns Offseason Moves
#
#                                         LLM_reasoning  \
# 0                     Tweets about NFL team fan gear.
# 1    Tweets discussing various NFL teams signing f...
# 2    Major signings and trades for the Atlanta Fal...
# 3    Tweets focus on sports, teams, and family-rel...
# 4    Discussions about NFL free agency signings an...
# 5    Tweets about various beauty services, haircut...
# 6    Tweets discussing NFL free agency moves, trad...
# 7    Tweets about the Arizona Cardinals signing va...
# 8    Tweets promoting fan apparel and accessories ...
# 9    Discusses the Pittsburgh Steelers signing mul...
# 10   Tweets about the Washington Commanders signin...
# 11   Tweets discussing the Houston Texans' offseas...
# 12   Tweets discussing NFL free agency news, playe...
# 13   Tweets about sports teams, collectibles, and ...
# 14   Tweets discussing the Dallas Cowboys releasin...
# 15   Discusses trades and signings by the Chicago ...
# 16   Discusses the Jaguars' offseason signings and...
# 17   Tweets discussing the Detroit Lions signing v...
# 18   A collection of tweets discussing various spo...
# 19   A collection of tweets about upcoming events,...
# 20             Tweets promoting NFL team merchandise.
# 21    Focus on Kansas City Chiefs and related topics.
# 22   This cluster of tweets is about the Philadelp...
# 23   Discusses upcoming free agency moves in the NFL.
# 24   The majority of tweets discuss the Minnesota ...
# 25   Tweets about new and vintage sneakers availab...
# 26   Tweets about the Carolina Panthers signing ne...
# 27   Discusses the Baltimore Ravens signing multip...
# 28   This cluster consists of tweets about NFL tea...
# 29   Tweets about the Philadelphia Eagles football...
# 30   Tweets about the Green Bay Packers signing ne...
# 31   Tweets about the Seattle Seahawks signing var...
# 32   Tweets about the retirement of Aaron Donald, ...
# 33   Tweets about the Miami Dolphins signing vario...
# 34   Tweets about various NFL teams, players, and ...
# 35   Discusses the trade of Kenny Pickett from the...
# 36   Tweets about shopping for sports-related gift...
# 37   Tweets expressing support for the Las Vegas R...
# 38   The majority of tweets discuss the New York J...
# 39   Focus on new NFL players and their rookie cards.
# 40   Tweets are about buying and selling homes, ho...
# 41   Tweets about NFL players signing new contract...
# 42   Updates on the Indianapolis Colts' free agenc...
# 43   Tweets are promoting a shopping experience fo...
# 44   Tweets discussing the Tennessee Titans signin...
# 45   Tweets discussing the New England Patriots si...
# 46   Tweets about various NFL teams, jerseys, and ...
# 47   Tweets discussing the Tampa Bay Buccaneers si...
# 48   Focus on NFL, NBA, and baseball rookie cards,...
# 49   Discusses the trade of OLB Brian Burns from t...
# 50   Tweets discussing the New York Giants' offsea...
# 51   Tweets discussing the Cleveland Browns' offse...
#
#                                                tf_idf  \
# 0                             ('life', 'fan', 'link')
# 1                ('ers', 'ninergang', 'sanfrancisco')
# 2                ('nfl', 'atlantafalcons', 'falcons')
# 3                   ('ers', 'niners', 'sanfrancisco')
# 4                         ('year', 'signing', 'deal')
# 5       ('newyorkartist', 'newyorkgiants', 'newyork')
# 6           ('nfl', 'chargers', 'losangeleschargers')
# 7            ('nfl', 'arizonacardinals', 'cardinals')
# 8                     ('click', 'range', 'fantastic')
# 9    ('pittsburghsteelers', 'steelers', 'pittsburgh')
# 10      ('nfl', 'washingtoncommanders', 'commanders')
# 11                 ('nfl', 'texans', 'houstontexans')
# 12                      ('nfl', 'sports', 'football')
# 13        ('paniniamerica', 'hof', 'baltimoreravens')
# 14             ('dallascowboys', 'cowboys', 'dallas')
# 15                   ('nfl', 'chicagobears', 'bears')
# 16          ('jaguars', 'nfl', 'jacksonvillejaguars')
# 17               ('detroit', 'lions', 'detroitlions')
# 18       ('neworleans', 'neworleanssaints', 'saints')
# 19                         ('com', 'order', 'online')
# 20                           ('click', 'life', 'fan')
# 21              ('chiefs', 'nfl', 'kansascitychiefs')
# 22                         ('eagles', 'year', 'deal')
# 23                      ('nfl', 'sports', 'football')
# 24                          ('jones', 'nfl', 'aaron')
# 25                   ('size', 'website', 'available')
# 26   ('keeppounding', 'carolinapanthers', 'panthers')
# 27               ('nfl', 'ravens', 'baltimoreravens')
# 28                       ('must', 'clicking', 'game')
# 29  ('flyeaglesfly', 'gobirds', 'philadelphiaeagles')
# 30              ('greenbaypackers', 'nfl', 'packers')
# 31             ('nfl', 'seahawks', 'seattleseahawks')
# 32                  ('rams', 'nfl', 'losangelesrams')
# 33            ('miamidolphins', 'dolphins', 'finsup')
# 34                      ('nfl', 'sports', 'football')
# 35                   ('kenny', 'pickett', 'steelers')
# 36                      ('secure', 'safe', 'payment')
# 37     ('lasvegasraiders', 'raidernation', 'raiders')
# 38                     ('nfl', 'newyorkjets', 'jets')
# 39                 ('nfl', 'panini', 'footballcards')
# 40  ('tampabaybuccaneers', 'tampabay', 'tampaflori...
# 41            ('nfl', 'americanfootball', 'football')
# 42              ('colts', 'nfl', 'indianapoliscolts')
# 43       ('chargers', 'losangeleschargers', 'boltup')
# 44               ('titans', 'nfl', 'tennesseetitans')
# 45   ('newengland', 'newenglandpatriots', 'patriots')
# 46                        ('nfl', 'ebay', 'football')
# 47        ('tampabaybuccaneers', 'buccaneers', 'nfl')
# 48   ('thehobby', 'whodoyoucollect', 'footballcards')
# 49                 ('nfl', 'giants', 'newyorkgiants')
# 50                 ('nfl', 'giants', 'newyorkgiants')
# 51         ('cleveland', 'browns', 'clevelandbrowns')
#
#                                              examples
# 0   [Explore our selection fan gear designed eleva...
# 1   [The Falcons have agreed terms with former ers...
# 2   [BREAKING The Atlanta Falcons are signing Darn...
# 3   [tiig pink phoenix rookie ers sanfrancisco ers...
# 4   [Free agent tight end Irv Smith reached agreem...
# 5   [have the PRETTIEST clients Loving the placeme...
# 6   [The Chargers have agreed terms bring back Eas...
# 7   [The Cardinals signed former Seahawks running ...
# 8   [Wear your Team pride with our exclusive range...
# 9   [honor Patrick Queen and Deshone Elliot coming...
# 10  [Cardinals are signing Jonah Williams year dea...
# 11  [Breaking The Texans are signing former Bills ...
# 12  [Greatest receiver all time Beautiful PSA Type...
# 13  [The sun out spring near and have great collec...
# 14  [boys bangtanboys myboys cowboys momofboys dal...
# 15  [just leave this here KNEW this was coming jus...
# 16  [How you feel about the Jags WRs following fre...
# 17  [Breaking The Lions have agreed terms with Mar...
# 18  [Exciting news for Saints fans Tyrann Mathieu ...
# 19  [Shoutout boy therealhefehoncho for picking th...
# 20  [Customize your outfit with our mix and match ...
# 21  [Hollywood heads Marquise Brown signs with the...
# 22  [BREAKING The Eagles are signing Devin White o...
# 23  [need Hunter like need air How would you rank ...
# 24  [BREAKING Minnesota Vikings jjettas reportedly...
# 25  [Nike Off White Summit White Psychic Purple Ai...
# 26  [The Panthers have signed former Seahawks guar...
# 27  [Who would you rather have the Ravens sign fre...
# 28  [Get ready for game day with our selection tai...
# 29  [Successful day Florida for brandon marsh Phil...
# 30  [GoPackGo PackersNation GreenBayPackers, Just ...
# 31  [Sorry little late this but the seahawks are t...
# 32  [Thank you Aaron Donald for being the best the...
# 33  [The Dolphins restructured Jalen Ramsey contra...
# 34  [Here are winners and losers from free agency ...
# 35  [Trade Steelers are sending Kenny Pickett the ...
# 36  [Thank you djack BuffaloBills bills billsmafia...
# 37  [And just like that The Raiders make SPLASH mo...
# 38  [Free agent Jadeveon Clowney meeting with the ...
# 39  [BEAUTY pulled yesterday from Panini Spectra A...
# 40  [The Falcons home model green architecture mas...
# 41  [und Returner Ray Ray McCloud unterschreibt ei...
# 42  [indianapoliscolts keep their star, The Colts ...
# 43  [Explore our selection fan gear designed eleva...
# 44  [Last month the titans broke ground the New Ni...
# 45  [The Patriots are signing guard Nick Leverett ...
# 46  [Please Email You Need Logo Can Help What You ...
# 47  [man word Let gooooooo gobucs firethecannons b...
# 48  [Another nice Edgerrin added the forever This ...
# 49  [TRADE SIGNED Yesterday the Carolina Panthers ...
# 50  [Patriots Jalen Mills joining the New York Gia...
# 51  [With the addition former round pick Jerry Jeu...
